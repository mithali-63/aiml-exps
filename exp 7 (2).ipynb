# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns 
df=pd.read_csv("Weight of copper dataset.csv")
df
# Out:
#      Unnamed: 0  power_rating  weight_of_copper category
# 0             1         16.46             34.69     high
# 1             2         12.52             28.78     high
# 2             3          7.66             21.48     high
# 3             4         21.09             41.64     high
# 4             5         24.43             46.64     high
# ..          ...           ...               ...      ...
# 430         431         24.94             47.41     high
# 431         432          8.55             22.82     high
# 432         433         19.82             39.73     high
# 433         434         37.08             65.62     high
# 434         435          7.31             20.96     high
#
# [435 rows x 4 columns]

# %%
plt.xlabel('POWER RATING')
plt.ylabel('AMOUNT OF COPPER')
plt.title('COPPER PREDICTION IN GENERATOR')
plt.hist(df[['power_rating','weight_of_copper']])
# Out:
# (array([[ 72., 102.,  75.,  73.,  62.,  51.,   0.,   0.,   0.,   0.],
#         [  0.,  17.,  52.,  72.,  58.,  46.,  56.,  42.,  40.,  52.]]),
#  array([ 5.07, 13.05, 21.03, 29.01, 36.99, 44.97, 52.95, 60.93, 68.91,
#         76.89, 84.87]),
#  <a list of 2 BarContainer objects>)

# %%
from sklearn.model_selection import train_test_split
x=np.array(df['power_rating'])
y=df['weight_of_copper']
x_train,x_test,y_train,y_test=train_test_split(x.reshape(-1,1),y,test_size=0.3)

# %%
len(x_train)
# Out:
# 304

# %%
len(y_train)
# Out:
# 304

# %%
len(x_test)
# Out:
# 131

# %%
len(y_test)
# Out:
# 131

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_pred=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9999999270483738

# %%
model.predict([[6.29]])
# Out:
# array([19.43533399])
